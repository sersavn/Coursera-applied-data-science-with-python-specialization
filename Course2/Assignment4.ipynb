# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **weather phenomena** (see below) for the region of **St Petersburg, St.-Petersburg, Russia**, or **Russia** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **St Petersburg, St.-Petersburg, Russia** to Ann Arbor, USA. In that case at least one source file must be about **St Petersburg, St.-Petersburg, Russia**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **St Petersburg, St.-Petersburg, Russia** and **weather phenomena**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **weather phenomena**?  For this category you might want to consider seasonal changes, natural disasters, or historical trends.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %% [markdown]
# # F1 analysis
#
# ## 1 Region and Domain
#
# Formula One (also Formula 1 or F1) is the highest class of single-seater international auto racing.
# Thus, Formula One region is worldwide and Formula 1 is related to the autosport.
#
# https://en.wikipedia.org/wiki/Formula_One

# %% [markdown]
# ## 2 Research Question
#
# What is amount of total races, amount of wins and home country for the pilots, who won Formula 1 at least once.
#
# Pilots from which country trends to be more successfull in terms of relationship of wins to amount of finished races?

# %% [markdown]
# ## 3 Links
#
# Whole dataset used in the assignment is represented by user https://www.kaggle.com/cjgdev
#
# Used dataset has a following link :
# https://www.kaggle.com/cjgdev/formula-1-race-data-19502017/data
#
# In the current assignment following csv tables were used:
# •
# •
# •

# %% [markdown]
# ## 4 Image
#
# You must upload an image which addresses the research question you stated. In addition to addressing
# the question, this visual should follow Cairo’s principles of truthfulness, functionality,
# beauty, and insightfulness.

# %% [markdown]
# ## 5 Discussion
#
# You must contribute a short (1-2 paragraph) written justification of how your visualization
# addresses your stated research question.
# This visualization was concerned with answering the question of how the win percentages of the four
# major Detroit sports teams (The Detroit Pistons, The Red Wings, The Detroit Tigers, and The Detroit
# Lions) have changed over the last 40 years. Wikipedia was scraped for data concerning wins and losses
# by season for each team. Any tie games were dropped from the analysis in order to provide a more
# level comparison between the sports. A 10 year moving average was plotted to help the reader identify
# any major trends in the team’s win percentages.
#
# The plot indicates years of high win percentage for The Detroit Pistons around 1990 and 2005,
# with periods of decline following both high points. The Detroit Red Wings’ win percentage shows an
# increase in the 1990’s and stays high through the early 2000’s, with a downward trend in recent years.
# The Detroit Tiger’s win percentage shows less variation than the other teams, hovering around 50%,
# with it’s lowest win percentage in the early 2000’s. The win percentage of the Detroit Lions shows low
# levels throughout the early 2000’s, with an increase after 2010

# %% [markdown]
# # Code

# %% [markdown]
# ### Introducing the initial data

# %%
import os
import pandas as pd
import glob

# %%
path =r'C:\WorkData\GitStaff\Applied Data Science with Python\Course2\f1data'
all_files = glob.glob(os.path.join(path, "*.csv")) #make list of paths

filenames = []
filecontent = []
for file in all_files:
    file_name = os.path.splitext(os.path.basename(file))[0]
    filenames.append(file_name)
    dfn = pd.read_csv(file, encoding='latin1') #encoding='latin1', #encoding='iso-8859-1' #encoding='cp1252'
    filecontent.append(dfn)

print(filenames)
# Out:
# ['circuits', 'constructorResults', 'constructors', 'constructorStandings', 'countries', 'drivers', 'driverStandings', 'lapTimes', 'pitStops', 'qualifying', 'races', 'results', 'seasons', 'status']

# %%
circuits = filecontent[0]
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya     MontmelÌ_
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng   alt  \
# 0  Australia -37.84970  144.96800  10.0
# 1   Malaysia   2.76083  101.73800   NaN
# 2    Bahrain  26.03250   50.51060   NaN
# 3      Spain  41.57000    2.26111   NaN
# 4     Turkey  40.95170   29.40500   NaN
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park

# %%
constructorResults = filecontent[1]
constructorResults.head()
# Out:
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0    NaN
# 1                     2      18              2     8.0    NaN
# 2                     3      18              3     9.0    NaN
# 3                     4      18              4     5.0    NaN
# 4                     5      18              5     2.0    NaN

# %%
constructors = filecontent[2]
constructors = constructors.drop(columns = ['Unnamed: 5','constructorRef','url','nationality'])
constructors.head()
# Out:
#    constructorId        name
# 0              1     McLaren
# 1              2  BMW Sauber
# 2              3    Williams
# 3              4     Renault
# 4              5  Toro Rosso

# %%
constructorStandings = filecontent[3]
constructorStandings.head()
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins  Unnamed: 7
# 0            1     1         NaN
# 1            3     0         NaN
# 2            2     0         NaN
# 3            4     0         NaN
# 4            5     0         NaN

# %%
drivers = filecontent[5]
drivers.head()
# Out:
#    driverId   driverRef  number code  forename     surname         dob  \
# 0         1    hamilton    44.0  HAM     Lewis    Hamilton  07/01/1985
# 1         2    heidfeld     NaN  HEI      Nick    Heidfeld  10/05/1977
# 2         3     rosberg     6.0  ROS      Nico     Rosberg  27/06/1985
# 3         4      alonso    14.0  ALO  Fernando      Alonso  29/07/1981
# 4         5  kovalainen     NaN  KOV    Heikki  Kovalainen  19/10/1981
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
driverStandings = filecontent[6]
driverStandings.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
lapTimes = filecontent[7]
lapTimes.head()
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
pitStops = filecontent[8]
pitStops.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
qualifying = filecontent[9]
qualifying.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
races = filecontent[10]
racesDate = races[['raceId', 'date' ,'name']]
racesDate = racesDate.rename({'name': 'Track'}, axis=1)
racesDate.head()
# Out:
#    raceId        date                  Track
# 0       1  2009-03-29  Australian Grand Prix
# 1       2  2009-04-05   Malaysian Grand Prix
# 2       3  2009-04-19     Chinese Grand Prix
# 3       4  2009-04-26     Bahrain Grand Prix
# 4       5  2009-05-10     Spanish Grand Prix

# %%
results = filecontent[11]
results.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
#
#   positionText  positionOrder  points  laps     time  milliseconds  \
# 0            1              1    10.0    58  34:50.6     5690616.0
# 1            2              2     8.0    58    5.478     5696094.0
# 2            3              3     6.0    58    8.163     5698779.0
# 3            4              4     5.0    58   17.181     5707797.0
# 4            5              5     4.0    58   18.014     5708630.0
#
#    fastestLap  rank fastestLapTime fastestLapSpeed  statusId
# 0        39.0   2.0        01:27.5           218.3         1
# 1        41.0   3.0        01:27.7         217.586         1
# 2        41.0   5.0        01:28.1         216.719         1
# 3        58.0   7.0        01:28.6         215.464         1
# 4        43.0   1.0        01:27.4         218.385         1

# %%
seasons = filecontent[12]
seasons.head()
# Out:
#    year                                                url
# 0  2009  http://en.wikipedia.org/wiki/2009_Formula_One_...
# 1  2008  http://en.wikipedia.org/wiki/2008_Formula_One_...
# 2  2007  http://en.wikipedia.org/wiki/2007_Formula_One_...
# 3  2006  http://en.wikipedia.org/wiki/2006_Formula_One_...
# 4  2005  http://en.wikipedia.org/wiki/2005_Formula_One_...

# %%
status = filecontent[13]
status.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
for l in range(len(filecontent)):
    print(filenames[l], len(filecontent[l]))
# Out:
# circuits 73
# constructorResults 11142
# constructors 208
# constructorStandings 11896
# countries 124
# drivers 842
# driverStandings 31726
# lapTimes 426633
# pitStops 6251
# qualifying 7516
# races 997
# results 23777
# seasons 69
# status 134

# %% [markdown]
# ### Modyfying the introduced datasets in order to show only winner results

# %%
import numpy as np

#driverStandingsWin = driverStandings.groupby('driverId', as_index=False)['wins'].sum()#.max()#.count()
#driverStandingsWin

Winners = results.loc[results['positionOrder'] == 1]
WinnersModified = Winners.copy()
WinnersModified = WinnersModified.drop(columns = ['laps','time', 'milliseconds', 'fastestLap', 'fastestLapTime', 'fastestLapSpeed','positionText','positionOrder','rank','points'])
WinnersModified.head()
# Out:
#     resultId  raceId  driverId  constructorId  number  grid  position  \
# 0          1      18         1              1    22.0     1       1.0
# 22        23      19         8              6     1.0     2       1.0
# 44        45      20        13              6     2.0     2       1.0
# 66        67      21         8              6     1.0     1       1.0
# 88        89      22        13              6     2.0     1       1.0
#
#     statusId
# 0          1
# 22         1
# 44         1
# 66         1
# 88         1

# %%
DriversWinAmount = Winners.groupby('driverId', as_index=False)['position'].sum()
DriversWinAmount.sort_values(['position'], axis=0, ascending=False, inplace = True)
DriversWinAmount.rename(columns = {'position' : 'TotalWins'}, inplace = True)
DriversWinAmount.head()
# Out:
#     driverId  TotalWins
# 15        30       91.0
# 0          1       62.0
# 29       117       51.0
# 11        20       47.0
# 27       102       41.0

# %%
#Winners = DriversWinAmount.merge(Winners, how='inner')
WinnersModified = WinnersModified.merge(DriversWinAmount, how='inner')
WinnersModified.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1       109      23         1              1    22.0     3       1.0
# 2       169      26         1              1    22.0     4       1.0
# 3       189      27         1              1    22.0     1       1.0
# 4       329      34         1              1    22.0     1       1.0
#
#    statusId  TotalWins
# 0         1       62.0
# 1         1       62.0
# 2         1       62.0
# 3         1       62.0
# 4         1       62.0

# %%
drivers = drivers[['driverId', 'nationality', 'dob','forename','surname']]
drivers.head()
# Out:
#    driverId nationality         dob  forename     surname
# 0         1     British  07/01/1985     Lewis    Hamilton
# 1         2      German  10/05/1977      Nick    Heidfeld
# 2         3      German  27/06/1985      Nico     Rosberg
# 3         4     Spanish  29/07/1981  Fernando      Alonso
# 4         5     Finnish  19/10/1981    Heikki  Kovalainen

# %%
countries = filecontent[4]
countries.drop(['ISO','Country'], axis=1, inplace = True)
countries.rename(columns = {'Nationality' : 'nationality'}, inplace = True)
countries.head()
# Out:
#   Code nationality
# 0   AD    Andorian
# 1   AE     Emirian
# 2   AF     Afghani
# 3   AI   Anguillan
# 4   AM    Armenian

# %%
WinnersModified = drivers.merge(WinnersModified, how='inner')
WinnersModified = WinnersModified.merge(countries, how ='inner')
WinnersModified = WinnersModified.merge(constructors, how ='inner')
WinnersModified = racesDate.merge(WinnersModified, how ='inner')
WinnersModified.head()
# Out:
#    raceId        date                  Track  driverId nationality  \
# 0       1  2009-03-29  Australian Grand Prix        18     British
# 1       2  2009-04-05   Malaysian Grand Prix        18     British
# 2       3  2009-04-19     Chinese Grand Prix        20      German
# 3       4  2009-04-26     Bahrain Grand Prix        18     British
# 4       5  2009-05-10     Spanish Grand Prix        18     British
#
#           dob   forename surname  resultId  constructorId  number  grid  \
# 0  19/01/1980     Jenson  Button      7554             23    22.0     1
# 1  19/01/1980     Jenson  Button      7574             23    22.0     1
# 2  03/07/1987  Sebastian  Vettel      7594              9    15.0     1
# 3  19/01/1980     Jenson  Button      7614             23    22.0     4
# 4  19/01/1980     Jenson  Button      7634             23    22.0     1
#
#    position  statusId  TotalWins Code      name
# 0       1.0         1       15.0   GB     Brawn
# 1       1.0         1       15.0   GB     Brawn
# 2       1.0         1       47.0   DE  Red Bull
# 3       1.0         1       15.0   GB     Brawn
# 4       1.0         1       15.0   GB     Brawn

# %%
WinnersModified = WinnersModified.drop(columns = ['raceId','resultId','constructorId','number','statusId'])

# %%
WinnersModified.head()
# Out:
#          date                  Track  driverId nationality         dob  \
# 0  2009-03-29  Australian Grand Prix        18     British  19/01/1980
# 1  2009-04-05   Malaysian Grand Prix        18     British  19/01/1980
# 2  2009-04-19     Chinese Grand Prix        20      German  03/07/1987
# 3  2009-04-26     Bahrain Grand Prix        18     British  19/01/1980
# 4  2009-05-10     Spanish Grand Prix        18     British  19/01/1980
#
#     forename surname  grid  position  TotalWins Code      name
# 0     Jenson  Button     1       1.0       15.0   GB     Brawn
# 1     Jenson  Button     1       1.0       15.0   GB     Brawn
# 2  Sebastian  Vettel     1       1.0       47.0   DE  Red Bull
# 3     Jenson  Button     4       1.0       15.0   GB     Brawn
# 4     Jenson  Button     1       1.0       15.0   GB     Brawn

# %%
WinnersModified['date'] = pd.to_datetime(WinnersModified['date'])

# %%
#Drivers with more amount of accidents quit the f1 earlier than drivers with less amount of accidents
dfAccidents = results[['resultId', 'raceId', 'driverId', 'constructorId','laps', 'statusId']]

#exceptionlaps = [1,range(11,19)]
exceptions1 = [x for x in range(11,20)]
exceptions2 = [1,45,50,128,53,55,58,88,122,123,124,125,127,133,134]
exceptions3 = [x for x in range(111,121)]
exceptions = exceptions1 + exceptions2 + exceptions3


RaceIsNotFinished = dfAccidents.loc[~dfAccidents['statusId'].isin(exceptions)]
RaceIsFinished = dfAccidents.loc[dfAccidents['statusId'].isin(exceptions)]

RaceIsFinishedLaps = RaceIsFinished.groupby('driverId').count()['raceId'].copy()
RaceIsFinishedLaps.sort_values(ascending=False, inplace = True)

RaceIsNotFinishedLaps = RaceIsNotFinished.groupby('driverId').count()['raceId'].copy()
RaceIsNotFinishedLaps.sort_values(ascending=False, inplace = True)

RaceTotal = dfAccidents.groupby('driverId').count()['raceId'].copy()
RaceTotal.sort_values(ascending=False, inplace = True)

result = pd.concat([RaceIsFinishedLaps.rename('FinishedRaces'), RaceIsNotFinishedLaps.rename('NotFinishedRaces'), RaceTotal.rename('TotalRaces')], axis=1)
result.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)
# 350          Johnny      Herbert    14       1.0        3.0   GB
# 353           Damon         Hill     3       1.0       22.0   GB
# 375         Jacques   Villeneuve     1       1.0       11.0   CA
# 386         Gerhard       Berger     1       1.0       10.0   AS
# 396         Olivier        Panis    14       1.0        1.0   FR
# 397            Jean        Alesi     5       1.0        1.0   FR
# 398           Nigel      Mansell     1       1.0       31.0   GB
# 429           Alain        Prost     1       1.0       51.0   FR
# 480          Ayrton        Senna     3       1.0       41.0   BR
# 521        Riccardo      Patrese     2       1.0        6.0   IT
# 527          Nelson       Piquet     8       1.0       23.0   BR
# 550         Thierry      Boutsen     1       1.0        3.0   BE
# ..              ...          ...   ...       ...        ...  ...
# 857        Wolfgang    von Trips     2       1.0        2.0   DE
# 859            Phil         Hill     1       1.0        3.0   US
# 862       Giancarlo     Baghetti    12       1.0        1.0   IT
# 863           Innes      Ireland     8       1.0        1.0   GB
# 864             Jim     Rathmann     2       1.0        1.0   US
# 865          Rodger         Ward     6       1.0        1.0   US
# 866              Jo      Bonnier     1       1.0        1.0   SE
# 867            Tony       Brooks     1       1.0        6.0   GB
# 873         Maurice  Trintignant     5       1.0        2.0   FR
# 875           Jimmy        Bryan     7       1.0        1.0   US
# 876            Mike     Hawthorn     1       1.0        3.0   GB
# 879           Peter      Collins     6       1.0        3.0   GB
# 882            Juan       Fangio     2       1.0       24.0   AR
# 906             Sam        Hanks    13       1.0        1.0   US
# 907           Luigi        Musso     3       1.0        1.0   IT
# 908             Pat     Flaherty     1       1.0        1.0   US
# 909             Bob     Sweikert    14       1.0        1.0   US
# 910            Bill     Vukovich    19       1.0        2.0   US
# 912  JosÌ© FroilÌÁn    GonzÌÁlez     2       1.0        2.0   AR
# 914         Alberto       Ascari     1       1.0       13.0   IT
# 927            Nino       Farina     3       1.0        5.0   IT
# 932           Piero      Taruffi     2       1.0        1.0   IT
# 933            Troy      Ruttman     7       1.0        1.0   US
# 934           Luigi      Fagioli     7       1.0        1.0   IT
# 935         Johnnie      Parsons     5       1.0        1.0   US
# 936            Nico      Rosberg     1       1.0       23.0   DE
# 959          Pastor    Maldonado     1       1.0        1.0   VE
# 960          Daniel    Ricciardo     6       1.0        5.0   AU
# 965             Max   Verstappen     4       1.0        3.0   NL
# 968        Valtteri       Bottas     3       1.0        3.0   FI
#
#              name  FinishedRaces  NotFinishedRaces  TotalRaces
# 0           Brawn          232.0              77.0         309
# 15       Red Bull          167.0              32.0         199
# 62       Red Bull          158.0              59.0         217
# 71        McLaren          183.0              25.0         208
# 133         Brawn          224.0             102.0         326
# 144       Ferrari          208.0              65.0         273
# 164       Ferrari          225.0              46.0         271
# 175    BMW Sauber           63.0              13.0          76
# 176       McLaren           89.0              23.0         112
# 177       Renault          233.0              60.0         293
# 209       Renault          157.0              74.0         231
# 212       Ferrari          238.0              70.0         308
# 303       Renault          162.0              94.0         256
# 304       McLaren          165.0              82.0         247
# 317      Williams          118.0              62.0         180
# 323       McLaren           98.0              67.0         165
# 343       Ferrari           82.0              65.0         147
# 347        Jordan           89.0              70.0         159
# 350       Stewart           82.0              83.0         165
# 353        Jordan           74.0              48.0         122
# 375      Williams          103.0              62.0         165
# 386      Benetton          115.0              95.0         210
# 396        Ligier           95.0              63.0         158
# 397       Ferrari          114.0              88.0         202
# 398      Williams           91.0             101.0         192
# 429      Williams          137.0              65.0         202
# 480       McLaren           97.0              65.0         162
# 521      Williams          112.0             145.0         257
# 527      Benetton          116.0              91.0         207
# 550      Williams           93.0              71.0         164
# ..            ...            ...               ...         ...
# 857       Ferrari           15.0              13.0          28
# 859       Ferrari           30.0              22.0          52
# 862       Ferrari           10.0              16.0          26
# 863  Lotus-Climax           25.0              30.0          55
# 864        Watson            8.0               4.0          12
# 865        Watson            3.0               9.0          12
# 866           BRM           48.0              61.0         109
# 867       Ferrari           21.0              20.0          41
# 873        Cooper           43.0              44.0          87
# 875       Epperly            6.0               3.0           9
# 876       Ferrari           32.0              16.0          48
# 879       Ferrari           16.0              21.0          37
# 882      Maserati           44.0              14.0          58
# 906       Epperly            5.0               4.0           9
# 907       Ferrari           14.0              12.0          26
# 908        Watson            3.0               3.0           6
# 909  Kurtis Kraft            3.0               2.0           5
# 910  Kurtis Kraft            2.0               3.0           5
# 912       Ferrari           19.0              10.0          29
# 914       Ferrari           22.0              14.0          36
# 927       Ferrari           26.0              11.0          37
# 932       Ferrari           12.0               6.0          18
# 933         Kuzma            4.0               5.0           9
# 934    Alfa Romeo            7.0               1.0           8
# 935  Kurtis Kraft            6.0               4.0          10
# 936      Mercedes          175.0              31.0         206
# 959      Williams           64.0              32.0          96
# 960      Red Bull          110.0              19.0         129
# 965      Red Bull           45.0              15.0          60
# 968      Mercedes           88.0              10.0          98
#
# [105 rows x 15 columns]

# %% [markdown]
# ### PLOT IT!

# %%
# %matplotlib notebook
import seaborn as sns
import matplotlib.pyplot as plt

# %%
notation = tuple(zip(Winners['TotalRaces'], Winners['TotalWins'], Winners['forename']+' '+ Winners['surname']))

# %%
plt.figure(figsize=(10,8))

plt.box(on=None)

ax = plt.gca()
ax.grid(color='black', linestyle='-', linewidth=0.05)

for elements in notation:    
    plt.annotate(elements[2], xy=((elements[0]*0.015+elements[0]), (elements[1]*0.03+elements[1])), alpha = elements[1]/Winners['TotalWins'].max())
    plt.scatter(x=elements[0], y=elements[1], alpha = (elements[1]+30)/(Winners['TotalWins'].max()+30), s = 10*elements[1], c = 'red')
#sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)
plt.gca().set_title('Racing performance of the F1 winners')#, fontstyle = 'italic')# , color='r')


plt.xlabel("Number of races")#, fontstyle = 'italic')# , color='r')
plt.ylabel("Victories")#, fontstyle = 'italic')#№ , color='r')

plt.savefig('Assignment4 visual', dpi=300, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None)
# Out:
# <img src="data:image/png;base64,..." width="1000">
