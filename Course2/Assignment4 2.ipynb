# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **weather phenomena** (see below) for the region of **St Petersburg, St.-Petersburg, Russia**, or **Russia** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **St Petersburg, St.-Petersburg, Russia** to Ann Arbor, USA. In that case at least one source file must be about **St Petersburg, St.-Petersburg, Russia**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **St Petersburg, St.-Petersburg, Russia** and **weather phenomena**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **weather phenomena**?  For this category you might want to consider seasonal changes, natural disasters, or historical trends.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %% [markdown]
# # F1 analysis
#
# ## 1 Region and Domain
#
# Formula One (also Formula 1 or F1) is the highest class of single-seater international auto racing.
#
# https://en.wikipedia.org/wiki/Formula_One

# %% [markdown]
# ## 2 Research Question
#
# You must state a question about the domain category and region that you identified as being
# interesting.
#
# How have the win percentages for the four major Detroit sports teams (The Detroit Pistons, The Red
# Wings, The Detroit Tigers, and The Detroit Lions) change over the last forty years?

# %% [markdown]
# ## 3 Links
#
# You must provide at least two links to publicly accessible datasets. These could be links to
# files such as CSV or Excel files, or links to websites which might have data in tabular form,
# such as Wikipedia pages.
# • https://en.wikipedia.org/wiki/List_of_Detroit_Pistons_seasons
# • https://en.wikipedia.org/wiki/List_of_Detroit_Red_Wings_seasons
# • https://en.wikipedia.org/wiki/List_of_Detroit_Tigers_seasons
# • https://en.wikipedia.org/wiki/List_of_Detroit_Lions_seasons

# %% [markdown]
# ## 4 Image
#
# You must upload an image which addresses the research question you stated. In addition to addressing
# the question, this visual should follow Cairo’s principles of truthfulness, functionality,
# beauty, and insightfulness.

# %% [markdown]
# ## 5 Discussion
#
# You must contribute a short (1-2 paragraph) written justification of how your visualization
# addresses your stated research question.
# This visualization was concerned with answering the question of how the win percentages of the four
# major Detroit sports teams (The Detroit Pistons, The Red Wings, The Detroit Tigers, and The Detroit
# Lions) have changed over the last 40 years. Wikipedia was scraped for data concerning wins and losses
# by season for each team. Any tie games were dropped from the analysis in order to provide a more
# level comparison between the sports. A 10 year moving average was plotted to help the reader identify
# any major trends in the team’s win percentages.
#
# The plot indicates years of high win percentage for The Detroit Pistons around 1990 and 2005,
# with periods of decline following both high points. The Detroit Red Wings’ win percentage shows an
# increase in the 1990’s and stays high through the early 2000’s, with a downward trend in recent years.
# The Detroit Tiger’s win percentage shows less variation than the other teams, hovering around 50%,
# with it’s lowest win percentage in the early 2000’s. The win percentage of the Detroit Lions shows low
# levels throughout the early 2000’s, with an increase after 2010

# %% [markdown]
# ### Introducing the initial data

# %%
import os
import pandas as pd
import glob

# %%
path =r'C:\WorkData\GitStaff\Applied Data Science with Python\Course2\f1data'
all_files = glob.glob(os.path.join(path, "*.csv")) #make list of paths

filenames = []
filecontent = []
for file in all_files:
    file_name = os.path.splitext(os.path.basename(file))[0]
    filenames.append(file_name)
    dfn = pd.read_csv(file, encoding='latin1') #encoding='latin1', #encoding='iso-8859-1' #encoding='cp1252'
    filecontent.append(dfn)

print(filenames)
# Out:
# ['circuits', 'constructorResults', 'constructors', 'constructorStandings', 'countries', 'drivers', 'driverStandings', 'lapTimes', 'pitStops', 'qualifying', 'races', 'results', 'seasons', 'status']

# %%
circuits = filecontent[0]
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya     MontmelÌ_
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng   alt  \
# 0  Australia -37.84970  144.96800  10.0
# 1   Malaysia   2.76083  101.73800   NaN
# 2    Bahrain  26.03250   50.51060   NaN
# 3      Spain  41.57000    2.26111   NaN
# 4     Turkey  40.95170   29.40500   NaN
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park

# %%
constructorResults = filecontent[1]
constructorResults.head()
# Out:
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0    NaN
# 1                     2      18              2     8.0    NaN
# 2                     3      18              3     9.0    NaN
# 3                     4      18              4     5.0    NaN
# 4                     5      18              5     2.0    NaN

# %%
constructors = filecontent[2]
constructors.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url  Unnamed: 5
# 0               http://en.wikipedia.org/wiki/McLaren         NaN
# 1            http://en.wikipedia.org/wiki/BMW_Sauber         NaN
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...         NaN
# 3            http://en.wikipedia.org/wiki/Renault_F1         NaN
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso         NaN

# %%
constructorStandings = filecontent[3]
constructorStandings.head()
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins  Unnamed: 7
# 0            1     1         NaN
# 1            3     0         NaN
# 2            2     0         NaN
# 3            4     0         NaN
# 4            5     0         NaN

# %%
drivers = filecontent[5]
drivers.head()
# Out:
#    driverId   driverRef  number code  forename     surname         dob  \
# 0         1    hamilton    44.0  HAM     Lewis    Hamilton  07/01/1985
# 1         2    heidfeld     NaN  HEI      Nick    Heidfeld  10/05/1977
# 2         3     rosberg     6.0  ROS      Nico     Rosberg  27/06/1985
# 3         4      alonso    14.0  ALO  Fernando      Alonso  29/07/1981
# 4         5  kovalainen     NaN  KOV    Heikki  Kovalainen  19/10/1981
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
driverStandings = filecontent[6]
driverStandings.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
lapTimes = filecontent[7]
lapTimes.head()
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
pitStops = filecontent[8]
pitStops.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
qualifying = filecontent[9]
qualifying.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
races = filecontent[10]
races.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
results = filecontent[11]
results.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
#
#   positionText  positionOrder  points  laps     time  milliseconds  \
# 0            1              1    10.0    58  34:50.6     5690616.0
# 1            2              2     8.0    58    5.478     5696094.0
# 2            3              3     6.0    58    8.163     5698779.0
# 3            4              4     5.0    58   17.181     5707797.0
# 4            5              5     4.0    58   18.014     5708630.0
#
#    fastestLap  rank fastestLapTime fastestLapSpeed  statusId
# 0        39.0   2.0        01:27.5           218.3         1
# 1        41.0   3.0        01:27.7         217.586         1
# 2        41.0   5.0        01:28.1         216.719         1
# 3        58.0   7.0        01:28.6         215.464         1
# 4        43.0   1.0        01:27.4         218.385         1

# %%
seasons = filecontent[12]
seasons.head()
# Out:
#    year                                                url
# 0  2009  http://en.wikipedia.org/wiki/2009_Formula_One_...
# 1  2008  http://en.wikipedia.org/wiki/2008_Formula_One_...
# 2  2007  http://en.wikipedia.org/wiki/2007_Formula_One_...
# 3  2006  http://en.wikipedia.org/wiki/2006_Formula_One_...
# 4  2005  http://en.wikipedia.org/wiki/2005_Formula_One_...

# %%
status = filecontent[13]
status.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
for l in range(len(filecontent)):
    print(filenames[l], len(filecontent[l]))
# Out:
# circuits 73
# constructorResults 11142
# constructors 208
# constructorStandings 11896
# countries 124
# drivers 842
# driverStandings 31726
# lapTimes 426633
# pitStops 6251
# qualifying 7516
# races 997
# results 23777
# seasons 69
# status 134

# %% [markdown]
# ### Modyfying the table in order to show only winner results

# %%
import numpy as np

#driverStandingsWin = driverStandings.groupby('driverId', as_index=False)['wins'].sum()#.max()#.count()
#driverStandingsWin

Winners = results.loc[results['positionOrder'] == 1]
Winners.head()
# Out:
#     resultId  raceId  driverId  constructorId  number  grid  position  \
# 0          1      18         1              1    22.0     1       1.0
# 22        23      19         8              6     1.0     2       1.0
# 44        45      20        13              6     2.0     2       1.0
# 66        67      21         8              6     1.0     1       1.0
# 88        89      22        13              6     2.0     1       1.0
#
#    positionText  positionOrder  points  laps     time  milliseconds  \
# 0             1              1    10.0    58  34:50.6     5690616.0
# 22            1              1    10.0    56  31:18.6     5478555.0
# 44            1              1    10.0    57  31:07.0     5466970.0
# 66            1              1    10.0    66  38:19.1     5899051.0
# 88            1              1    10.0    58  26:49.5     5209451.0
#
#     fastestLap  rank fastestLapTime fastestLapSpeed  statusId
# 0         39.0   2.0        01:27.5           218.3         1
# 22        37.0   2.0        01:35.4         209.158         1
# 44        38.0   3.0        01:33.6         208.153         1
# 66        46.0   1.0        01:21.7         205.191         1
# 88        16.0   3.0        01:26.7         221.734         1

# %%
DriversWinAmount = Winners.groupby('driverId', as_index=False)['position'].sum()
DriversWinAmount.sort_values(['position'], axis=0, ascending=False, inplace = True)
DriversWinAmount.rename(columns = {'position' : 'TotalWins'}, inplace = True)
DriversWinAmount.head()
# Out:
#     driverId  TotalWins
# 15        30       91.0
# 0          1       62.0
# 29       117       51.0
# 11        20       47.0
# 27       102       41.0

# %%
Winners = Winners.merge(DriversWinAmount, how='outer')
Winners.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1       109      23         1              1    22.0     3       1.0
# 2       169      26         1              1    22.0     4       1.0
# 3       189      27         1              1    22.0     1       1.0
# 4       329      34         1              1    22.0     1       1.0
#
#   positionText  positionOrder  points  laps     time  milliseconds  \
# 0            1              1    10.0    58  34:50.6     5690616.0
# 1            1              1    10.0    76  00:42.7     7242742.0
# 2            1              1    10.0    60  39:09.4     5949440.0
# 3            1              1    10.0    67  31:20.9     5480874.0
# 4            1              1    10.0    56  31:57.4     5517403.0
#
#    fastestLap  rank fastestLapTime fastestLapSpeed  statusId  TotalWins
# 0        39.0   2.0        01:27.5           218.3         1       62.0
# 1        71.0   6.0        01:18.5         153.152         1       62.0
# 2        16.0   3.0        01:32.8         199.398         1       62.0
# 3        17.0   2.0        01:16.0         216.552         1       62.0
# 4        13.0   1.0        01:36.3         203.722         1       62.0

# %%
drivers = drivers[['driverId', 'nationality', 'dob']]
drivers.head()
# Out:
#    driverId nationality         dob
# 0         1     British  07/01/1985
# 1         2      German  10/05/1977
# 2         3      German  27/06/1985
# 3         4     Spanish  29/07/1981
# 4         5     Finnish  19/10/1981

# %%
countries = filecontent[4]
countries.drop(['ISO','Country'], axis=1, inplace = True)
countries.rename(columns = {'Nationality' : 'nationality'}, inplace = True)
countries.head()
# Out:
#   Code nationality
# 0   AD    Andorian
# 1   AE     Emirian
# 2   AF     Afghani
# 3   AI   Anguillan
# 4   AM    Armenian

# %%
drivers = drivers.merge(countries, how='outer')
drivers
# Out:
#      driverId    nationality         dob Code
# 0         1.0        British  07/01/1985   GB
# 1        14.0        British  27/03/1971   GB
# 2        18.0        British  19/01/1980   GB
# 3        19.0        British  18/04/1979   GB
# 4        51.0        British  31/07/1978   GB
# 5        56.0        British  10/11/1965   GB
# 6        65.0        British  25/06/1964   GB
# 7        66.0        British  29/12/1969   GB
# 8        71.0        British  17/09/1960   GB
# 9        84.0        British  01/06/1959   GB
# 10       87.0        British  08/04/1966   GB
# 11       95.0        British  08/08/1953   GB
# 12      118.0        British  27/08/1954   GB
# 13      135.0        British  03/03/1961   GB
# 14      141.0        British  09/10/1961   GB
# 15      151.0        British  26/03/1964   GB
# 16      156.0        British  07/11/1956   GB
# 17      174.0        British  26/04/1958   GB
# 18      186.0        British  27/11/1957   GB
# 19      187.0        British  04/05/1946   GB
# 20      205.0        British  19/09/1946   GB
# 21      209.0        British  01/05/1951   GB
# 22      211.0        British  26/02/1955   GB
# 23      226.0        British  19/02/1952   GB
# 24      227.0        British  29/10/1951   GB
# 25      231.0        British  29/08/1947   GB
# 26      242.0        British  13/08/1944   GB
# 27      245.0        British  24/01/1943   GB
# 28      252.0        British  11/06/1949   GB
# 29      259.0        British  26/01/1945   GB
# ..        ...            ...         ...  ...
# 903       NaN       Namibian         NaN  NaN
# 904       NaN       Nigerian         NaN   NG
# 905       NaN      Norwegian         NaN   NO
# 906       NaN       Nepalese         NaN   NP
# 907       NaN          Omani         NaN   OM
# 908       NaN     Panamanian         NaN   PA
# 909       NaN       Peruvian         NaN   PE
# 910       NaN       Filipino         NaN   PH
# 911       NaN      Pakistani         NaN   PK
# 912       NaN      Portugees         NaN   PT
# 913       NaN     Paraguayan         NaN   PY
# 914       NaN         Qatari         NaN   QA
# 915       NaN       Romanian         NaN   RO
# 916       NaN  Saudi Arabian         NaN   SA
# 917       NaN    Seychellois         NaN   SC
# 918       NaN    Singaporean         NaN   SG
# 919       NaN      Slovakian         NaN   SK
# 920       NaN     Senegalese         NaN   SN
# 921       NaN         Somali         NaN   SO
# 922       NaN       Tunisian         NaN   TN
# 923       NaN        Turkish         NaN   TR
# 924       NaN      Taiwanese         NaN   TW
# 925       NaN      Tanzanian         NaN   TZ
# 926       NaN      Ukrainian         NaN   UA
# 927       NaN        Ugandan         NaN   UG
# 928       NaN    Uzbekistani         NaN   UZ
# 929       NaN     Vietnamese         NaN   VN
# 930       NaN         Yemeni         NaN   YE
# 931       NaN        Zambian         NaN   ZM
# 932       NaN     Zimbabwean         NaN   ZW
#
# [933 rows x 4 columns]

# %%
Winners = drivers.merge(Winners, how='inner')
#Winners.dropna(how = 'all', thresh = 5)
#Winners.dropna(how='all', inplace = True, thresh = 10, axis = 1) 
#Winners.dropna(axis=0, how = 'any', inplace = True)#!!!
Winners
# Out:
#     driverId    nationality         dob Code  resultId  raceId  constructorId  \
# 0          1        British  07/01/1985   GB         1      18              1
# 1          1        British  07/01/1985   GB       109      23              1
# 2          1        British  07/01/1985   GB       169      26              1
# 3          1        British  07/01/1985   GB       189      27              1
# 4          1        British  07/01/1985   GB       329      34              1
# 5          1        British  07/01/1985   GB       479      41              1
# 6          1        British  07/01/1985   GB       501      42              1
# 7          1        British  07/01/1985   GB       589      46              1
# 8          1        British  07/01/1985   GB       677      50              1
# 9          1        British  07/01/1985   GB      7734      10              1
# 10         1        British  07/01/1985   GB      7814      14              1
# 11         1        British  07/01/1985   GB     20467     343              1
# 12         1        British  07/01/1985   GB     20491     344              1
# 13         1        British  07/01/1985   GB     20611     349              1
# 14         1        British  07/01/1985   GB     20825     843              1
# 15         1        British  07/01/1985   GB     20992     850              1
# 16         1        British  07/01/1985   GB     21184     858              1
# 17         1        British  07/01/1985   GB     21376     866              1
# 18         1        British  07/01/1985   GB     21472     870              1
# 19         1        British  07/01/1985   GB     21520     872              1
# 20         1        British  07/01/1985   GB     21664     878              1
# 21         1        British  07/01/1985   GB     21910     890            131
# 22         1        British  07/01/1985   GB     22152     901            131
# 23         1        British  07/01/1985   GB     22174     902            131
# 24         1        British  07/01/1985   GB     22196     903            131
# 25         1        British  07/01/1985   GB     22218     904            131
# 26         1        British  07/01/1985   GB     22306     908            131
# 27         1        British  07/01/1985   GB     22395     912            131
# 28         1        British  07/01/1985   GB     22417     913            131
# 29         1        British  07/01/1985   GB     22439     914            131
# ..       ...            ...         ...  ...       ...     ...            ...
# 949      238        Swedish  14/02/1944   SE     15216     616             32
# 950      238        Swedish  14/02/1944   SE     15239     617             32
# 951      238        Swedish  14/02/1944   SE     15290     619             32
# 952      255        Swedish  20/11/1948   SE     13396     549             32
# 953      347        Swedish  31/01/1930   SE     18346     758             66
# 954      813     Venezuelan  09/03/1985   VE     21328     864              3
# 955      304  New Zealander  18/06/1936   NZ     14525     590              1
# 956      304  New Zealander  18/06/1936   NZ     15095     611              1
# 957      304  New Zealander  18/06/1936   NZ     15340     621              1
# 958      304  New Zealander  18/06/1936   NZ     16363     666            187
# 959      304  New Zealander  18/06/1936   NZ     16529     675            187
# 960      304  New Zealander  18/06/1936   NZ     16551     676            187
# 961      304  New Zealander  18/06/1936   NZ     16631     680            191
# 962      304  New Zealander  18/06/1936   NZ     16721     685            191
# 963      360  New Zealander  30/08/1937   NZ     16435     670            187
# 964      360  New Zealander  30/08/1937   NZ     17648     730            170
# 965      360  New Zealander  30/08/1937   NZ     18067     746            170
# 966      360  New Zealander  30/08/1937   NZ     18465     764            170
# 967      345        Mexican  18/01/1940   ME     15955     646             66
# 968      345        Mexican  18/01/1940   ME     16613     679            167
# 969      222  South African  29/01/1950   ZA     12508     517              6
# 970      222  South African  29/01/1950   ZA     12536     518              6
# 971      222  South African  29/01/1950   ZA     12692     524              6
# 972      222  South African  29/01/1950   ZA     13251     543             59
# 973      222  South African  29/01/1950   ZA     13370     548             59
# 974      222  South African  29/01/1950   ZA     13678     558             59
# 975      222  South African  29/01/1950   ZA     13886     566             25
# 976      222  South African  29/01/1950   ZA     14208     578             25
# 977      222  South African  29/01/1950   ZA     14689     596             25
# 978      222  South African  29/01/1950   ZA     14773     599             25
#
#      number  grid  position    ...    points  laps     time  milliseconds  \
# 0      22.0     1       1.0    ...      10.0    58  34:50.6     5690616.0
# 1      22.0     3       1.0    ...      10.0    76  00:42.7     7242742.0
# 2      22.0     4       1.0    ...      10.0    60  39:09.4     5949440.0
# 3      22.0     1       1.0    ...      10.0    67  31:20.9     5480874.0
# 4      22.0     1       1.0    ...      10.0    56  31:57.4     5517403.0
# 5       2.0     1       1.0    ...      10.0    70  44:11.3     6251292.0
# 6       2.0     1       1.0    ...      10.0    73  31:10.0     5469965.0
# 7       2.0     1       1.0    ...      10.0    70  35:53.0     5752991.0
# 8       2.0     1       1.0    ...      10.0    67  00:34.6     7234579.0
# 9       1.0     4       1.0    ...      10.0    70  38:23.9     5903876.0
# 10      1.0     1       1.0    ...      10.0    61  56:06.3     6966337.0
# 11      2.0     2       1.0    ...      25.0    58  28:47.6     5327620.0
# 12      2.0     1       1.0    ...      25.0    70  33:53.5     5633456.0
# 13      2.0     2       1.0    ...      25.0    44  29:04.3     5344268.0
# 14      3.0     3       1.0    ...      25.0    56  36:58.2     5818226.0
# 15      3.0     2       1.0    ...      25.0    60  37:30.3     5850334.0
# 16      3.0     2       1.0    ...      25.0    55  37:11.9     5831886.0
# 17      4.0     2       1.0    ...      25.0    70  32:29.6     5549586.0
# 18      4.0     1       1.0    ...      25.0    69  41:05.5     6065503.0
# 19      4.0     1       1.0    ...      25.0    53  19:41.2     4781221.0
# 20      4.0     2       1.0    ...      25.0    56  35:55.3     5755269.0
# 21     10.0     1       1.0    ...      25.0    70  42:29.4     6149445.0
# 22     44.0     1       1.0    ...      25.0    56  40:26.0     6025974.0
# 23     44.0     2       1.0    ...      25.0    57  39:42.7     5982743.0
# 24     44.0     1       1.0    ...      25.0    54  33:28.3     5608338.0
# 25     44.0     1       1.0    ...      25.0    66  41:05.2     6065155.0
# 26     44.0     6       1.0    ...      25.0    52  26:52.1     8812094.0
# 27     44.0     1       1.0    ...      25.0    53  19:10.2     4750236.0
# 12        62.0   2.0         01:17.8          201.778        1      62.0
# 13        32.0   1.0         01:49.1          231.178        1      62.0
# 14         NaN   0.0             NaN              NaN        1      62.0
# 15        59.0   1.0         01:34.3          196.526        1      62.0
# 16        51.0   3.0         01:43.5          193.255        1      62.0
# 17        59.0   6.0         01:17.0          203.837        1      62.0
# 18        65.0   4.0         01:25.7          184.082        1      62.0
# 19        52.0   5.0         01:28.4          235.841        1      62.0
# 20        55.0   5.0         01:39.7          199.047        1      62.0
# 21        69.0   3.0         01:24.6          186.322        1      62.0
# 22        53.0   1.0         01:43.1          193.611        1      62.0
# 23        49.0   2.0         01:37.1          200.634        1      62.0
# 24        42.0   2.0         01:41.2          193.916        1      62.0
# 25        54.0   3.0         01:29.5          187.275        1      62.0
# 26        26.0   1.0         01:37.2          218.239        1      62.0
# 27        29.0   1.0         01:28.0          236.975        1      62.0
# 28        39.0   1.0         01:50.4          165.137        1      62.0
# 29        39.0   1.0         01:51.6          187.322        1      62.0
# ..         ...   ...             ...              ...      ...       ...
# 949        NaN   NaN             NaN              NaN        1      10.0
# 950        NaN   NaN             NaN              NaN        1      10.0
# 951        NaN   NaN             NaN              NaN        1      10.0
# 952        NaN   NaN             NaN              NaN        1       1.0
# 953        NaN   NaN             NaN              NaN        1       1.0
# 954       26.0   6.0         01:27.9          190.635        1       1.0
# 955        NaN   NaN             NaN              NaN        1       8.0
# 956        NaN   NaN             NaN              NaN        1       8.0
# 957        NaN   NaN             NaN              NaN        1       8.0
# 958        NaN   NaN             NaN              NaN        1       8.0
# 959        NaN   NaN             NaN              NaN        1       8.0
# 960        NaN   NaN             NaN              NaN        1       8.0
# 961        NaN   NaN             NaN              NaN        1       8.0
# 962        NaN   NaN             NaN              NaN        1       8.0
# 963        NaN   NaN             NaN              NaN        1       4.0
# 964        NaN   NaN             NaN              NaN        1       4.0
# 965        NaN   NaN             NaN              NaN        1       4.0
# 966        NaN   NaN             NaN              NaN        1       4.0
# 967        NaN   NaN             NaN              NaN        1       2.0
# 968        NaN   NaN             NaN              NaN        1       2.0
# 969        NaN   NaN             NaN              NaN        1      10.0
# 970        NaN   NaN             NaN              NaN        1      10.0
# 971        NaN   NaN             NaN              NaN        1      10.0
# 972        NaN   NaN             NaN              NaN        1      10.0
# 973        NaN   NaN             NaN              NaN        1      10.0
# 974        NaN   NaN             NaN              NaN        1      10.0
# 975        NaN   NaN             NaN              NaN        1      10.0
# 976        NaN   NaN             NaN              NaN        1      10.0
# 977        NaN   NaN             NaN              NaN        1      10.0
# 978        NaN   NaN             NaN              NaN        1      10.0
#
# [979 rows x 22 columns]

# %%
WinnersCountry = (Winners[['driverId','Code', 'TotalWins','nationality', 'dob']]).copy()
#DataFrame.copy(deep=True)
WinnersCountry.groupby(['Code'], sort=True)
WinnersCountry.drop_duplicates(subset=None, keep='first', inplace=True)
WinnersCountry.dropna(axis=0, how = 'any', inplace = True)#!!!
WinnersCountry.sort_values('Code', inplace = True)
WinnersCountry
dfAccidents = results[['resultId', 'raceId', 'driverId', 'constructorId','laps', 'statusId']]

#exceptionlaps = [1,range(11,19)]
exceptions1 = [x for x in range(11,20)]
exceptions2 = [1,45,50,128,53,55,58,88,122,123,124,125,127,133,134]
exceptions3 = [x for x in range(111,121)]
exceptions = exceptions1 + exceptions2 + exceptions3


RaceIsNotFinished = dfAccidents.loc[~dfAccidents['statusId'].isin(exceptions)]
RaceIsFinished = dfAccidents.loc[dfAccidents['statusId'].isin(exceptions)]

RaceIsFinishedLaps = RaceIsFinished.groupby('driverId').count()['raceId'].copy()
RaceIsFinishedLaps.sort_values(ascending=False, inplace = True)

RaceIsNotFinishedLaps = RaceIsNotFinished.groupby('driverId').count()['raceId'].copy()
RaceIsNotFinishedLaps.sort_values(ascending=False, inplace = True)

RaceTotal = dfAccidents.groupby('driverId').count()['raceId'].copy()
RaceTotal.sort_values(ascending=False, inplace = True)

result = pd.concat([RaceIsFinishedLaps.rename('FinishedRaces'), RaceIsNotFinishedLaps.rename('NotFinishedRaces'), RaceTotal.rename('TotalRaces')], axis=1)
result.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)
result.reset_index(inplace = True)
result.head()
# Out:
#    driverId  FinishedRaces  NotFinishedRaces  TotalRaces
# 0         1          183.0              25.0         208
# 1         2          135.0              49.0         184
# 2         3          175.0              31.0         206
# 3         4          233.0              60.0         293
# 4         5           89.0              23.0         112

# %%
Winners = WinnersCountry.merge(result, how='inner')
Winners.drop(['driverId'], axis=1, inplace = True)
Winners.head()
#Winners
Winners.sort_values(['dob'], axis=0, ascending=False, inplace = True)
print(type(Winners['dob']))
for e in Winners['dob']:
    print(e, type(e))
Winners

https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html
# Out:
# <class 'pandas.core.series.Series'>
# 31/01/1930 <class 'str'>
# 30/10/1917 <class 'str'>
# 30/10/1906 <class 'str'>
# 30/09/1997 <class 'str'>
# 30/09/1946 <class 'str'>
# 30/08/1937 <class 'str'>
# 30/06/1975 <class 'str'>
# 29/08/1947 <class 'str'>
# 29/07/1981 <class 'str'>
# 29/01/1950 <class 'str'>
# 28/09/1968 <class 'str'>
# 28/08/1989 <class 'str'>
# 28/07/1924 <class 'str'>
# 28/02/1940 <class 'str'>
# 28/01/1926 <class 'str'>
# 27/08/1976 <class 'str'>
# 27/08/1959 <class 'str'>
# 27/06/1985 <class 'str'>
# 27/03/1971 <class 'str'>
# 27/02/1939 <class 'str'>
# 26/04/1937 <class 'str'>
# 26/03/1958 <class 'str'>
# 26/03/1952 <class 'str'>
# 25/12/1934 <class 'str'>
# 25/06/1964 <class 'str'>
# 25/06/1949 <class 'str'>
# 25/04/1981 <class 'str'>
# 25/02/1944 <class 'str'>
# 25/02/1932 <class 'str'>
# 24/06/1911 <class 'str'>
# 24/02/1955 <class 'str'>
# 23/12/1956 <class 'str'>
# 23/05/1972 <class 'str'>
# 22/02/1949 <class 'str'>
# 21/12/1935 <class 'str'>
# 21/11/1943 <class 'str'>
# 21/03/1960 <class 'str'>
# 21/02/1940 <class 'str'>
# ..                ...         ...
# 61               16.0          48
# 97                9.0          12
# 34               43.0          95
# 18               62.0         165
# 103              32.0          96
# 51              101.0         192
# 84               13.0          76
# 75               49.0          77
# 21               56.0         100
# 64               25.0         208
# 32               73.0         128
# 62               21.0          37
# 13               38.0          73
# 93                3.0           6
# 0                10.0          29
# 20               57.0         138
# 99               17.0          54
# 42               86.0         164
# 92                4.0          10
# 52               66.0         154
# 22               13.0          28
# 57               28.0          72
# 27               32.0         199
# 25               70.0         308
# 6                51.0         117
# 39               63.0         158
# 9                62.0         129
# 38               45.0          55
# 8                19.0         129
# 10               56.0         121
#
# [105 rows x 7 columns]

# %%
# %matplotlib notebook
import seaborn as sns
import matplotlib.pyplot as plt

fig = sns.pairplot(Winners, hue='nationality', diag_kind='hist', size=3)#, hue='Name', diag_kind='kde', size=2);
#fig = sns.pairplot(Winners, hue='nationality', diag_kind='hist', size=3)#, hue='Name', diag_kind='kde', size=2);
plt.savefig('DriversNationality', dpi=200, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None)
#DriversWinAmount.sort_values(['position'], axis=0, ascending=False, inplace = True)
# Out:
# <img src="data:image/png;base64,..." width="1354.9999798089268">

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '2.2.2'

# %%
sns.__version__
# Out:
# '0.8.1'

# %%
np.__version__
# Out:
# '1.14.0'

# %%
g = sns.PairGrid(Winners, y_vars=["TotalRaces"], x_vars=["TotalWins"], hue = 'nationality', size = 9)
#
g = g.map(plt.scatter)
# Out:
# <img src="data:image/png;base64,..." width="899.9999865889552">

# %%
g = sns.PairGrid(Winners, y_vars=["TotalRaces"], x_vars=["NotFinishedRaces"], hue = 'nationality', size = 9)
#
g = g.map(plt.scatter)
# Out:
# <img src="data:image/png;base64,..." width="899.9999865889552">

# %%
xValues = []
yValues = []

for a,b in WinnersCountry.iterrows():
    xValues.append(b[1])
    yValues.append(b[2])

# %%
'''
#plt.figure(figsize=(20,10))
fig = sns.pairplot(Winners, hue='nationality', diag_kind='hist', size=3)#, hue='Name', diag_kind='kde', size=2);
plt.savefig('DriversNationality', dpi=200, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None)

#allaxes = fig.get_axes()
'''
# Out:
# "\n#plt.figure(figsize=(20,10))\nfig = sns.pairplot(Winners, hue='nationality', diag_kind='hist', size=3)#, hue='Name', diag_kind='kde', size=2);\nplt.savefig('DriversNationality', dpi=200, facecolor='w', edgecolor='w',\n        orientation='portrait', papertype=None, format=None,\n        transparent=False, bbox_inches=None, pad_inches=0.1,\n        frameon=None)\n\n#allaxes = fig.get_axes()\n"

# %%
'''
print(xValues[2],yValues[2])
print(xValues[3],yValues[3])
plt.bar(xValues[0], yValues[0], bottom = 0)
plt.bar(xValues[1], yValues[1], bottom = yValues[0])
plt.bar(xValues[2], yValues[2], bottom = yValues[0] + yValues[1])
plt.bar(xValues[3], yValues[3], bottom = 0)
plt.bar(xValues[4], yValues[4], bottom = yValues[3])
plt.bar(xValues[5], yValues[5], bottom = yValues[4]+yValues[3])
plt.bar(xValues[6], yValues[6], bottom = 0)
plt.bar(xValues[7], yValues[7], bottom = yValues[6])
plt.bar(xValues[8], yValues[8], bottom = yValues[6] + yValues[7])
'''
# Out:
# '\nprint(xValues[2],yValues[2])\nprint(xValues[3],yValues[3])\nplt.bar(xValues[0], yValues[0], bottom = 0)\nplt.bar(xValues[1], yValues[1], bottom = yValues[0])\nplt.bar(xValues[2], yValues[2], bottom = yValues[0] + yValues[1])\nplt.bar(xValues[3], yValues[3], bottom = 0)\nplt.bar(xValues[4], yValues[4], bottom = yValues[3])\nplt.bar(xValues[5], yValues[5], bottom = yValues[4]+yValues[3])\nplt.bar(xValues[6], yValues[6], bottom = 0)\nplt.bar(xValues[7], yValues[7], bottom = yValues[6])\nplt.bar(xValues[8], yValues[8], bottom = yValues[6] + yValues[7])\n'

# %%
bottomlist = []
meter = 0

for n in range(len(xValues)):
    
    #CountryChamps = xValues.count(xValues[n])  
    #print(xValues[n])
    if meter == int(CountryChamps):
        print('refreshing list')
        meter = 0
        bottomlist = []
    CountryChamps = xValues.count(xValues[n])  
    if meter < int(CountryChamps):        
        plt.bar(xValues[n], yValues[n], bottom = sum(bottomlist))##0
        print('afterappend', xValues[n],yValues[n],bottomlist, sum(bottomlist), meter, CountryChamps)      
        bottomlist.append(yValues[n])
        meter +=1   
        #print('afterappend', xValues[n],yValues[n],bottomlist, sum(bottomlist), meter, CountryChamps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-153438c0808c> in <module>()
#       6     #CountryChamps = xValues.count(xValues[n])
#       7     #print(xValues[n])
# ----> 8     if meter == int(CountryChamps):
#       9         print('refreshing list')
#      10         meter = 0
#
# NameError: name 'CountryChamps' is not defined

# %% [markdown]
# ### Creating table with amount of finished/NotFinishedRaces

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

#result.plot()

#result.plot(x = result.index, y=['FinishedRaces','NotFinishedRaces', 'TotalRaces'], kind = 'area')
result.plot(x = result.index, y=['FinishedRaces','NotFinishedRaces'], kind = 'area')
plt.box(on=None)

# %%
from scipy.stats import ttest_ind

z = ttest_ind(result['FinishedRaces'], result['NotFinishedRaces'])
print(z)

# %%
countries = filecontent[4]
countries.drop(['ISO','Country'], axis=1, inplace = True)

# %%
df.groupby('StationID', as_index=False)['BiasTemp'].mean()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
fig = sns.pairplot(DriversNationality, hue='nationality', diag_kind='hist', size=3)#, hue='Name', diag_kind='kde', size=2);
#plt.savefig('DriversNationality', dpi=200, facecolor='w', edgecolor='w',
#        orientation='portrait', papertype=None, format=None,
#        transparent=False, bbox_inches=None, pad_inches=0.1,
#        frameon=None)

allaxes = fig.get_axes()

# %%
#mean, cov = [0, 1], [(1, .5), (.5, 1)]
#x, y = np.random.multivariate_normal(mean, cov, 1000).T
#print(x,y,type(x),type(y))

# %%
# %matplotlib notebook
plt.scatter(DriversNationality['Code'], DriversNationality['wins'])
#https://stackoverflow.com/questions/30482071/how-to-calculate-mean-values-grouped-on-another-column-in-pandas
