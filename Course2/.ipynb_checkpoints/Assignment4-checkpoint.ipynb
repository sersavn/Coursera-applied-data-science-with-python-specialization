# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **weather phenomena** (see below) for the region of **St Petersburg, St.-Petersburg, Russia**, or **Russia** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **St Petersburg, St.-Petersburg, Russia** to Ann Arbor, USA. In that case at least one source file must be about **St Petersburg, St.-Petersburg, Russia**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **St Petersburg, St.-Petersburg, Russia** and **weather phenomena**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **weather phenomena**?  For this category you might want to consider seasonal changes, natural disasters, or historical trends.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %% [markdown]
# # F1 analysis
#
# ## 1 Region and Domain
#
# Formula One (also Formula 1 or F1) is the highest class of single-seater international auto racing.
#
# https://en.wikipedia.org/wiki/Formula_One

# %% [markdown]
# ## 2 Research Question
#
# You must state a question about the domain category and region that you identified as being
# interesting.
#
# How have the win percentages for the four major Detroit sports teams (The Detroit Pistons, The Red
# Wings, The Detroit Tigers, and The Detroit Lions) change over the last forty years?

# %% [markdown]
# ## 3 Links
#
# You must provide at least two links to publicly accessible datasets. These could be links to
# files such as CSV or Excel files, or links to websites which might have data in tabular form,
# such as Wikipedia pages.
# • https://en.wikipedia.org/wiki/List_of_Detroit_Pistons_seasons
# • https://en.wikipedia.org/wiki/List_of_Detroit_Red_Wings_seasons
# • https://en.wikipedia.org/wiki/List_of_Detroit_Tigers_seasons
# • https://en.wikipedia.org/wiki/List_of_Detroit_Lions_seasons

# %% [markdown]
# ## 4 Image
#
# You must upload an image which addresses the research question you stated. In addition to addressing
# the question, this visual should follow Cairo’s principles of truthfulness, functionality,
# beauty, and insightfulness.

# %% [markdown]
# ## 5 Discussion
#
# You must contribute a short (1-2 paragraph) written justification of how your visualization
# addresses your stated research question.
# This visualization was concerned with answering the question of how the win percentages of the four
# major Detroit sports teams (The Detroit Pistons, The Red Wings, The Detroit Tigers, and The Detroit
# Lions) have changed over the last 40 years. Wikipedia was scraped for data concerning wins and losses
# by season for each team. Any tie games were dropped from the analysis in order to provide a more
# level comparison between the sports. A 10 year moving average was plotted to help the reader identify
# any major trends in the team’s win percentages.
#
# The plot indicates years of high win percentage for The Detroit Pistons around 1990 and 2005,
# with periods of decline following both high points. The Detroit Red Wings’ win percentage shows an
# increase in the 1990’s and stays high through the early 2000’s, with a downward trend in recent years.
# The Detroit Tiger’s win percentage shows less variation than the other teams, hovering around 50%,
# with it’s lowest win percentage in the early 2000’s. The win percentage of the Detroit Lions shows low
# levels throughout the early 2000’s, with an increase after 2010

# %%
import os
import pandas as pd
import glob

# %%
path =r'C:\WorkData\GitStaff\Applied Data Science with Python\Course2\f1data'
all_files = glob.glob(os.path.join(path, "*.csv")) #make list of paths

filenames = []
filecontent = []
for file in all_files:
    file_name = os.path.splitext(os.path.basename(file))[0]
    filenames.append(file_name)
    dfn = pd.read_csv(file, encoding='latin1') #encoding='latin1', #encoding='iso-8859-1' #encoding='cp1252'
    filecontent.append(dfn)

print(filenames)
# Out:
# ['circuits', 'constructorResults', 'constructors', 'constructorStandings', 'drivers', 'driverStandings', 'lapTimes', 'pitStops', 'qualifying', 'races', 'results', 'seasons', 'status']

# %%
circuits = filecontent[0]
circuits.head(5)
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya     MontmelÌ_
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng   alt  \
# 0  Australia -37.84970  144.96800  10.0
# 1   Malaysia   2.76083  101.73800   NaN
# 2    Bahrain  26.03250   50.51060   NaN
# 3      Spain  41.57000    2.26111   NaN
# 4     Turkey  40.95170   29.40500   NaN
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park

# %%
constructorResults = filecontent[1]
constructorResults.head(5)
# Out:
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0    NaN
# 1                     2      18              2     8.0    NaN
# 2                     3      18              3     9.0    NaN
# 3                     4      18              4     5.0    NaN
# 4                     5      18              5     2.0    NaN

# %%
constructors = filecontent[2]
constructors.head(5)
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url  Unnamed: 5
# 0               http://en.wikipedia.org/wiki/McLaren         NaN
# 1            http://en.wikipedia.org/wiki/BMW_Sauber         NaN
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...         NaN
# 3            http://en.wikipedia.org/wiki/Renault_F1         NaN
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso         NaN

# %%
constructorStandings = filecontent[3]
constructorStandings.head(5)
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins  Unnamed: 7
# 0            1     1         NaN
# 1            3     0         NaN
# 2            2     0         NaN
# 3            4     0         NaN
# 4            5     0         NaN

# %%
drivers = filecontent[4]
drivers.head(100)
# Out:
#     driverId           driverRef  number code         forename        surname  \
# 0          1            hamilton    44.0  HAM            Lewis       Hamilton
# 1          2            heidfeld     NaN  HEI             Nick       Heidfeld
# 2          3             rosberg     6.0  ROS             Nico        Rosberg
# 3          4              alonso    14.0  ALO         Fernando         Alonso
# 4          5          kovalainen     NaN  KOV           Heikki     Kovalainen
# 5          6            nakajima     NaN  NAK           Kazuki       Nakajima
# 6          7            bourdais     NaN  BOU       SÌ©bastien       Bourdais
# 7          8           raikkonen     7.0  RAI             Kimi    RÌ_ikkÌ¦nen
# 8          9              kubica     NaN  KUB           Robert         Kubica
# 9         10               glock     NaN  GLO             Timo          Glock
# 10        11                sato     NaN  SAT           Takuma           Sato
# 11        12           piquet_jr     NaN  PIQ           Nelson     Piquet Jr.
# 12        13               massa    19.0  MAS           Felipe          Massa
# 13        14           coulthard     NaN  COU            David      Coulthard
# 14        15              trulli     NaN  TRU            Jarno         Trulli
# 15        16               sutil    99.0  SUT           Adrian          Sutil
# 16        17              webber     NaN  WEB             Mark         Webber
# 17        18              button    22.0  BUT           Jenson         Button
# 18        19            davidson     NaN  DAV          Anthony       Davidson
# 19        20              vettel     5.0  VET        Sebastian         Vettel
# 20        21          fisichella     NaN  FIS        Giancarlo     Fisichella
# 21        22         barrichello     NaN  BAR           Rubens    Barrichello
# 22        23     ralf_schumacher     NaN  SCH             Ralf     Schumacher
# 23        24              liuzzi     NaN  LIU       Vitantonio         Liuzzi
# 24        25                wurz     NaN  WUR        Alexander           Wurz
# 25        26               speed     NaN  SPE            Scott          Speed
# 26        27              albers     NaN  ALB       Christijan         Albers
# 27        28   markus_winkelhock     NaN  WIN           Markus     Winkelhock
# 28        29            yamamoto     NaN  YAM            Sakon       Yamamoto
# 29        30  michael_schumacher     NaN  MSC          Michael     Schumacher
# ..       ...                 ...     ...  ...              ...            ...
# 70        71          damon_hill     NaN  NaN            Damon           Hill
# 71        72            sarrazin     NaN  NaN        StÌ©phane       Sarrazin
# 72        73              rosset     NaN  NaN          Ricardo         Rosset
# 73        74               tuero     NaN  NaN          Esteban          Tuero
# 74        75              nakano     NaN  NaN           Shinji         Nakano
# 75        76           magnussen     NaN  MAG              Jan      Magnussen
# 76        77              berger     NaN  NaN          Gerhard         Berger
# 77        78              larini     NaN  NaN           Nicola         Larini
# 78        79            katayama     NaN  NaN             Ukyo       Katayama
# 79        80             sospiri     NaN  NaN         Vincenzo        Sospiri
# 80        81          morbidelli     NaN  NaN           Gianni     Morbidelli
# 81        82             fontana     NaN  NaN         Norberto        Fontana
# 82        83                lamy     NaN  NaN            Pedro           Lamy
# 83        84             brundle     NaN  NaN           Martin        Brundle
# 84        85          montermini     NaN  NaN           Andrea     Montermini
# 85        86             lavaggi     NaN  NaN         Giovanni        Lavaggi
# 86        87            blundell     NaN  NaN             Mark       Blundell
# 87        88              suzuki     NaN  NaN            Aguri         Suzuki
# 88        89               inoue     NaN  NaN             Taki          Inoue
# 89        90              moreno     NaN  NaN          Roberto         Moreno
# 90        91          wendlinger     NaN  NaN             Karl     Wendlinger
# 91        92              gachot     NaN  NaN         Bertrand         Gachot
# 92        93       schiattarella     NaN  NaN         Domenico  Schiattarella
# 93        94             martini     NaN  NaN        Pierluigi        Martini
# 94        95             mansell     NaN  NaN            Nigel        Mansell
# 95        96            boullion     NaN  NaN  Jean-Christophe       Boullion
# 96        97               papis     NaN  NaN     Massimiliano          Papis
# 97        98            deletraz     NaN  NaN       Jean-Denis     DÌ©lÌ©traz
# 98        99            tarquini     NaN  NaN         Gabriele       Tarquini
# 99       100               comas     NaN  NaN            Ìärik          Comas
#
#            dob nationality                                                url
# 0   07/01/1985     British        http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1   10/05/1977      German         http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2   27/06/1985      German          http://en.wikipedia.org/wiki/Nico_Rosberg
# 3   29/07/1981     Spanish       http://en.wikipedia.org/wiki/Fernando_Alonso
# 4   19/10/1981     Finnish     http://en.wikipedia.org/wiki/Heikki_Kovalainen
# 5   11/01/1985    Japanese       http://en.wikipedia.org/wiki/Kazuki_Nakajima
# 6   28/02/1979      French  http://en.wikipedia.org/wiki/S%C3%A9bastien_Bo...
# 7   17/10/1979     Finnish  http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C...
# 8   07/12/1984      Polish         http://en.wikipedia.org/wiki/Robert_Kubica
# 9   18/03/1982      German            http://en.wikipedia.org/wiki/Timo_Glock
# 10  28/01/1977    Japanese           http://en.wikipedia.org/wiki/Takuma_Sato
# 11  25/07/1985   Brazilian    http://en.wikipedia.org/wiki/Nelson_Piquet,_Jr.
# 12  25/04/1981   Brazilian          http://en.wikipedia.org/wiki/Felipe_Massa
# 13  27/03/1971     British       http://en.wikipedia.org/wiki/David_Coulthard
# 14  13/07/1974     Italian          http://en.wikipedia.org/wiki/Jarno_Trulli
# 15  11/01/1983      German          http://en.wikipedia.org/wiki/Adrian_Sutil
# 16  27/08/1976  Australian           http://en.wikipedia.org/wiki/Mark_Webber
# 17  19/01/1980     British         http://en.wikipedia.org/wiki/Jenson_Button
# 18  18/04/1979     British      http://en.wikipedia.org/wiki/Anthony_Davidson
# 19  03/07/1987      German      http://en.wikipedia.org/wiki/Sebastian_Vettel
# 20  14/01/1973     Italian  http://en.wikipedia.org/wiki/Giancarlo_Fisichella
# 21  23/05/1972   Brazilian    http://en.wikipedia.org/wiki/Rubens_Barrichello
# 22  30/06/1975      German       http://en.wikipedia.org/wiki/Ralf_Schumacher
# 23  06/08/1980     Italian     http://en.wikipedia.org/wiki/Vitantonio_Liuzzi
# 24  15/02/1974    Austrian        http://en.wikipedia.org/wiki/Alexander_Wurz
# 25  24/01/1983    American           http://en.wikipedia.org/wiki/Scott_Speed
# 26  16/04/1979       Dutch     http://en.wikipedia.org/wiki/Christijan_Albers
# 27  13/06/1980      German     http://en.wikipedia.org/wiki/Markus_Winkelhock
# 28  09/07/1982    Japanese        http://en.wikipedia.org/wiki/Sakon_Yamamoto
# 29  03/01/1969      German    http://en.wikipedia.org/wiki/Michael_Schumacher
# ..         ...         ...                                                ...
# 70  17/09/1960     British            http://en.wikipedia.org/wiki/Damon_Hill
# 71  02/11/1975      French  http://en.wikipedia.org/wiki/St%C3%A9phane_Sar...
# 72  27/07/1968   Brazilian        http://en.wikipedia.org/wiki/Ricardo_Rosset
# 73  22/04/1978   Argentine         http://en.wikipedia.org/wiki/Esteban_Tuero
# 74  01/04/1971    Japanese         http://en.wikipedia.org/wiki/Shinji_Nakano
# 75  04/07/1973      Danish         http://en.wikipedia.org/wiki/Jan_Magnussen
# 76  27/08/1959    Austrian        http://en.wikipedia.org/wiki/Gerhard_Berger
# 77  19/03/1964     Italian         http://en.wikipedia.org/wiki/Nicola_Larini
# 78  29/05/1963    Japanese         http://en.wikipedia.org/wiki/Ukyo_Katayama
# 79  07/10/1966     Italian      http://en.wikipedia.org/wiki/Vincenzo_Sospiri
# 80  13/01/1968     Italian     http://en.wikipedia.org/wiki/Gianni_Morbidelli
# 81  20/01/1975   Argentine      http://en.wikipedia.org/wiki/Norberto_Fontana
# 82  20/03/1972  Portuguese            http://en.wikipedia.org/wiki/Pedro_Lamy
# 83  01/06/1959     British        http://en.wikipedia.org/wiki/Martin_Brundle
# 84  30/05/1964     Italian     http://en.wikipedia.org/wiki/Andrea_Montermini
# 85  18/02/1958     Italian      http://en.wikipedia.org/wiki/Giovanni_Lavaggi
# 86  08/04/1966     British         http://en.wikipedia.org/wiki/Mark_Blundell
# 87  08/09/1960    Japanese          http://en.wikipedia.org/wiki/Aguri_Suzuki
# 88  05/09/1963    Japanese            http://en.wikipedia.org/wiki/Taki_Inoue
# 89  11/02/1959   Brazilian        http://en.wikipedia.org/wiki/Roberto_Moreno
# 90  20/12/1968    Austrian       http://en.wikipedia.org/wiki/Karl_Wendlinger
# 91  23/12/1962     Belgian       http://en.wikipedia.org/wiki/Bertrand_Gachot
# 92  17/11/1967     Italian  http://en.wikipedia.org/wiki/Domenico_Schiatta...
# 93  23/04/1961     Italian     http://en.wikipedia.org/wiki/Pierluigi_Martini
# 94  08/08/1953     British         http://en.wikipedia.org/wiki/Nigel_Mansell
# 95  27/12/1969      French  http://en.wikipedia.org/wiki/Jean-Christophe_B...
# 96  03/10/1969     Italian    http://en.wikipedia.org/wiki/Massimiliano_Papis
# 97  01/10/1963       Swiss   http://en.wikipedia.org/wiki/Jean-Denis_Deletraz
# 98  02/03/1962     Italian     http://en.wikipedia.org/wiki/Gabriele_Tarquini
# 99  28/09/1963      French       http://en.wikipedia.org/wiki/%C3%89rik_Comas
#
# [100 rows x 9 columns]

# %%
driverStandings = filecontent[5]
driverStandings.head(5)
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
lapTimes = filecontent[6]
lapTimes.head(5)
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
pitStops = filecontent[7]
pitStops.head(5)
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
qualifying = filecontent[8]
qualifying.head(5)
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
races = filecontent[9]
races.head(5)
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
results = filecontent[10]
results.head(5)
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
#
#   positionText  positionOrder  points  laps     time  milliseconds  \
# 0            1              1    10.0    58  34:50.6     5690616.0
# 1            2              2     8.0    58    5.478     5696094.0
# 2            3              3     6.0    58    8.163     5698779.0
# 3            4              4     5.0    58   17.181     5707797.0
# 4            5              5     4.0    58   18.014     5708630.0
#
#    fastestLap  rank fastestLapTime fastestLapSpeed  statusId
# 0        39.0   2.0        01:27.5           218.3         1
# 1        41.0   3.0        01:27.7         217.586         1
# 2        41.0   5.0        01:28.1         216.719         1
# 3        58.0   7.0        01:28.6         215.464         1
# 4        43.0   1.0        01:27.4         218.385         1

# %%
#Drivers with more amount of accidents quit the f1 earlier than drivers with less amount of accidents
dfAccidents = results[['resultId', 'raceId', 'driverId', 'constructorId','laps', 'statusId']]

#exceptionlaps = [1,range(11,19)]
exceptions1 = [x for x in range(11,20)]
exceptions2 = [1,45,50,128,53,55,58,88,122,123,124,125,127,133,134]
exceptions3 = [x for x in range(111,121)]
exceptions = exceptions1 + exceptions2 + exceptions3


RaceIsNotFinished = dfAccidents.loc[~dfAccidents['statusId'].isin(exceptions)]
RaceIsFinished = dfAccidents.loc[dfAccidents['statusId'].isin(exceptions)]

RaceIsFinishedLaps = RaceIsFinished.groupby('driverId').count()['raceId'].copy()
RaceIsFinishedLaps.sort_values(ascending=False, inplace = True)

RaceIsNotFinishedLaps = RaceIsNotFinished.groupby('driverId').count()['raceId'].copy()
RaceIsNotFinishedLaps.sort_values(ascending=False, inplace = True)

RaceTotal = dfAccidents.groupby('driverId').count()['raceId'].copy()
RaceTotal.sort_values(ascending=False, inplace = True)

result = pd.concat([RaceIsFinishedLaps.rename('FinishedRaces'), RaceIsNotFinishedLaps.rename('NotFinishedRaces'), RaceTotal.rename('TotalRaces')], axis=1)
result.sort_values(['TotalRaces'], axis=0, ascending=True, inplace=True)

result.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)
result.reset_index(inplace = True)
result
#result
#result['FinishedRaces']
# Out:
#      driverId  FinishedRaces  NotFinishedRaces  TotalRaces
# 0         759            1.0               1.0           2
# 1         494            1.0               1.0           2
# 2         249            1.0               1.0           2
# 3         690            1.0               1.0           2
# 4         511            1.0               1.0           2
# 5         379            1.0               1.0           2
# 6         489            1.0               1.0           2
# 7         799            1.0               1.0           2
# 8         517            1.0               1.0           2
# 9         744            1.0               1.0           2
# 10        116            1.0               1.0           2
# 11        302            1.0               1.0           2
# 12        392            1.0               1.0           2
# 13        784            1.0               1.0           2
# 14        785            1.0               1.0           2
# 15        412            1.0               1.0           2
# 16        409            1.0               1.0           2
# 17        407            1.0               1.0           2
# 18        400            1.0               1.0           2
# 19        768            1.0               1.0           2
# 20        273            1.0               1.0           2
# 21        274            1.0               1.0           2
# 22        771            1.0               1.0           2
# 23        282            1.0               1.0           2
# 24        772            1.0               1.0           2
# 25        770            1.0               1.0           2
# 26        623            1.0               1.0           2
# 27        710            1.0               1.0           2
# 28        168            1.0               1.0           2
# 29        595            1.0               1.0           2
# ..        ...            ...               ...         ...
# 531        35          103.0              62.0         165
# 532        84           76.0              89.0         165
# 533        65           82.0              83.0         165
# 534        57           98.0              67.0         165
# 535       182           87.0              87.0         174
# 536       289           96.0              83.0         179
# 537       172           86.0              94.0         180
# 538        23          118.0              62.0         180
# 539         2          135.0              49.0         184
# 540        95           91.0             101.0         192
# 541        20          167.0              32.0         199
# 542       117          137.0              65.0         202
# 543        55          114.0              88.0         202
# 544         3          175.0              31.0         206
# 545       137          116.0              91.0         207
# 546         1          183.0              25.0         208
# 547        77          115.0              95.0         210
# 548       110           61.0             153.0         214
# 549       105           91.0             124.0         215
# 550        17          158.0              59.0         217
# 551        21          157.0              74.0         231
# 552        14          165.0              82.0         247
# 553        15          162.0              94.0         256
# 554       119          112.0             145.0         257
# 555        13          225.0              46.0         271
# 556         8          208.0              65.0         273
# 557         4          233.0              60.0         293
# 558        30          238.0              70.0         308
# 559        18          232.0              77.0         309
# 560        22          224.0             102.0         326
#
# [561 rows x 4 columns]

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

#result.plot()

#result.plot(x = result.index, y=['FinishedRaces','NotFinishedRaces', 'TotalRaces'], kind = 'area')
result.plot(x = result.index, y=['FinishedRaces','NotFinishedRaces'], kind = 'area')
plt.box(on=None)
#(=None, y=None, kind='line',

'''
kind : str

‘line’ : line plot (default)
‘bar’ : vertical bar plot
‘barh’ : horizontal bar plot
‘hist’ : histogram
‘box’ : boxplot
‘kde’ : Kernel Density Estimation plot
‘density’ : same as ‘kde’
‘area’ : area plot
‘pie’ : pie plot
‘scatter’ : scatter plot
‘hexbin’ : hexbin plot
'''
#plt.figure(4, figsize=(9,6))
#plt.box(on=None)
#ax = plt.gca()
#plt.plot(result.index, result['FinishedRaces'])
#plt.plot(result.index, result['NotFinishedRaces'])
#plt.plot(result['TotalRaces'])
#plt.plot(RaceIsNotFinished.index,RaceIsNotFinished.values)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# '\nkind : str\n\n‘line’ : line plot (default)\n‘bar’ : vertical bar plot\n‘barh’ : horizontal bar plot\n‘hist’ : histogram\n‘box’ : boxplot\n‘kde’ : Kernel Density Estimation plot\n‘density’ : same as ‘kde’\n‘area’ : area plot\n‘pie’ : pie plot\n‘scatter’ : scatter plot\n‘hexbin’ : hexbin plot\n'

# %%
from scipy.stats import ttest_ind

z = ttest_ind(result['FinishedRaces'], result['NotFinishedRaces'])
print(z)
# Out:
# Ttest_indResult(statistic=1.793739573552391, pvalue=0.07312441836841442)

# %%
seasons = filecontent[11]
seasons.head(5)
# Out:
#    year                                                url
# 0  2009  http://en.wikipedia.org/wiki/2009_Formula_One_...
# 1  2008  http://en.wikipedia.org/wiki/2008_Formula_One_...
# 2  2007  http://en.wikipedia.org/wiki/2007_Formula_One_...
# 3  2006  http://en.wikipedia.org/wiki/2006_Formula_One_...
# 4  2005  http://en.wikipedia.org/wiki/2005_Formula_One_...

# %%
status = filecontent[12]
status
# Out:
#      statusId            status
# 0           1          Finished
# 1           2      Disqualified
# 2           3          Accident
# 3           4         Collision
# 4           5            Engine
# 5           6           Gearbox
# 6           7      Transmission
# 7           8            Clutch
# 8           9        Hydraulics
# 9          10        Electrical
# 10         11            +1 Lap
# 11         12           +2 Laps
# 12         13           +3 Laps
# 13         14           +4 Laps
# 14         15           +5 Laps
# 15         16           +6 Laps
# 16         17           +7 Laps
# 17         18           +8 Laps
# 18         19           +9 Laps
# 19         20          Spun off
# 20         21          Radiator
# 21         22        Suspension
# 22         23            Brakes
# 23         24      Differential
# 24         25       Overheating
# 25         26        Mechanical
# 26         27              Tyre
# 27         28       Driver Seat
# 28         29          Puncture
# 29         30        Driveshaft
# ..        ...               ...
# 104       105       Spark plugs
# 105       106         Fuel pipe
# 106       107        Eye injury
# 107       108          Oil pipe
# 108       109              Axle
# 109       110        Water pipe
# 110       111          +14 Laps
# 111       112          +15 Laps
# 112       113          +25 Laps
# 113       114          +18 Laps
# 114       115          +22 Laps
# 115       116          +16 Laps
# 116       117          +24 Laps
# 117       118          +29 Laps
# 118       119          +23 Laps
# 119       120          +21 Laps
# 120       121           Magneto
# 121       122          +44 Laps
# 122       123          +30 Laps
# 123       124          +19 Laps
# 124       125          +46 Laps
# 125       126      Supercharger
# 126       127          +20 Laps
# 127       130  Collision damage
# 128       131        Power Unit
# 129       132               ERS
# 130       133          +49 Laps
# 131       134          +38 Laps
# 132       135        Brake duct
# 133       136              Seat
#
# [134 rows x 2 columns]
