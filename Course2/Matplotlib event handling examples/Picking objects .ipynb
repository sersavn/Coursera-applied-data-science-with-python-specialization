# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
import random

fig = plt.figure()

g1 = random.sample(range(1, 100), 10)
g2 = random.sample(range(1, 100), 10)
g3 = np.repeat(50, 10)

l1 = plt.plot(g1, picker = 5, color = 'red')
l2 = plt.plot(g2, picker = 5, color = 'blue')
l3 = plt.plot(g3, picker = 5, color = 'green')

lines = [l1,l2,l3]
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#print(l1,type(l1))
g = plt.gca().get_contains
print(g,type(g))
b = plt.gca().get_lines()
print(b)
# Out:
# <bound method Artist.get_contains of <matplotlib.axes._subplots.AxesSubplot object at 0x0000020871FAD6D8>> <class 'method'>
# <a list of 3 Line2D objects>

# %%
#hit, props = onpick(artist, 'pick_event')
def onpick(event):
    #return event.ind[:]
    #plt.gca().set_title('{}'.format(plt.get_fignums())) #returns figure number
    #plt.gca().set_title('{}'.format(fig.get_axes())) # returns matplotlib.axes._subplot.AxesSubplot object at ....  
    #plt.gca().set_title('{}'.format(plt.gca().get_children()[0:3])) # returns children
    #plt.gca().set_title('{}'.format(event.ind[:])) # returns the x value of the selected plot
    #plt.gca().set_title('{}'.format(l1event.ind[:])) # returns the x value of the selected plot
    #plt.gca().set_title('{}'.format(plt.gca().get_picker())) # returns None
    plt.gca().set_title('{}'.format(plt.gca().get_contains)) # returns None
    
    
    #plt.gca().set_title('{}'.format(plt.gca().get_lines())) # returns 3 line 2d objects
    #plt.gca().set_title('{}'.format(plt.gca().event.artist())) # returns a list of the lines
    #plt.gca().set_title('{}'.format(lines[event.artist])) # returns a list of the lines
    #plt.gca().set_title('{}'.format(plt.gca().get_cursor_data)) # returns a list of the lines
    #plt.gca().set_title('{}'.format(plt.gca().contains))
    #plt.gca().set_title('{}'.format(plt.gca().get_contains))
    #Axes.get_cursor_data	Get the cursor data for a given event.
    #Axes.get_cursor_props
    #Axes.get_picker
    #matplotlib.artist.Artist.contains
plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 7
